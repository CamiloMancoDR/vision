# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Cargar la imagen
img = cv2.imread('Hongo.png',0)

# Aplicar umbralización
ret,th = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)

# Crear el kernel
kernel = np.ones((5,5),np.uint8)
#kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (30,1))
#kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (30,30))
#kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (5,5))

# Aplicar dilatación, erosión, apertura, cierre, gradiente, tophat y blackhat
#dilatacion = cv2.dilate(th, kernel, iterations=1)
#erosion = cv2.erode(th, kernel, iterations=1)
#apertura = cv2.morphologyEx(th, cv2.MORPH_OPEN, kernel)
#cierre = cv2.morphologyEx(th, cv2.MORPH_CLOSE, kernel)
#gradiente = cv2.morphologyEx(th, cv2.MORPH_GRADIENT, kernel)


# Mostrar imágenes utilizando cv2_imshow
cv2_imshow(th)
#cv2_imshow(dilatacion)
#cv2_imshow(erosion)
#cv2_imshow(apertura)
#cv2_imshow(cierre)
#cv2_imshow(gradiente)


cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1000x1000>
# <PIL.Image.Image image mode=L size=1000x1000>
